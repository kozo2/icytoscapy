# %% [markdown]
# # Sample Workflow with Cytoscape and Cytoscape.js

# %%
from IPython.html.widgets import interact
from IPython.html.widgets import *
from IPython.html import widgets
import cytoscape.viewer as cy
import json
import networkx as nx
from igraph import *

# %matplotlib inline
import matplotlib.pyplot as plt

import requests

import pandas as pd

# %%
# Make sure Cytoscape  RESTful API is running!
cytoscape_version = requests.get('http://localhost:8080/v1/version')
print("Cytoscape version is " +  json.loads(cytoscape_version.text)["cytoscapeVersion"])

res = requests.get('http://localhost:8080/v1/networks/count')
print(res.text)
# Out:
# Cytoscape version is 3.1.0
# {"networkCount":10}

# %% [markdown]
# ## Import & Generate Data in Python
#
# ### Generate scale-free graphs with NetworkX

# %%
graphs = []

for i in range(10):
    # Generate scale-free graph
    g = nx.scale_free_graph(200);
    
    # Perform simple graph analysis
    
    # Node statistics
    bc = nx.betweenness_centrality(g)
    degree = nx.degree(g)
    cc = nx.closeness_centrality(g)
    nx.set_node_attributes(g, 'betweenness', bc)
    nx.set_node_attributes(g, 'closeness', cc)
    nx.set_node_attributes(g, 'degree', degree)
    
    # Network statistics
    g.graph["avg_shortest_path_len"] = nx.average_shortest_path_length(g)
    g.graph["density"] = nx.density(g)
    graphs.append(g)


# Calculate statistics on the network

# Visualize with matplotlib
# nx.draw(graphs[0])
# plt.show()

# %% [markdown]
# ### Send all network models to Cytoscape

# %%
# Remove all networks
requests.delete('http://localhost:8080/v1/networks')

headers = {'Content-Type': 'application/json'}

for graph in graphs:
    cyjs_network = cy.from_networkx(graph)
    res1 = requests.post("http://localhost:8080/v1/networks?collection=Networks1", data=json.dumps(cyjs_network), headers=headers)
    result = json.loads(res1.content)
    network_suid = result["networkSUID"]
    res2 = requests.get("http://localhost:8080/v1/apply/layouts/force-directed/" + str(network_suid))

# %% [markdown]
# ## (Now graphs are in Cytoscape.  Do analysis, visualization, etc...)

# %% [markdown]
# ## Get the visualization back to this notebook.

# %%
# Load Visual Style file
vs_collection = json.load(open('kegg_style.json'))

styles = {}
for style in vs_collection:
    style_settings = style['style']
    title = style['title']
    styles[title] = style_settings


response = requests.get("http://localhost:8080/v1/networks?format=SUID")
network_list = json.loads(response.content)
print(network_list)

network_views = []
for suid in network_list:
    response2 = requests.get("http://localhost:8080/v1/networks/" + str(suid) + "/views/first")
    network_views.append(json.loads(response2.content))

# %%
cy.render(network_views[5], styles["default"])
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cy6226c87f-e025-4c04-965b-54dd3717a6ef {
#         height: 700px;
#         width: 1160px;
#         position: absolute;
"position": {"y": -262.9809355187416, "x": 270.0738015317917}, "selected": false, "data": {"name": "188", "degree": 1, "SUID": 74308, "selected": false, "closeness": 0.03840812100704527, "betweenness": 0.0, "shared_name": "188", "id": "188"}}, {"position": {"y": 118.10982375860215, "x": -199.04007290363313}, "selected": false, "data": {"name": "187", "degree": 2, "SUID": 74307, "selected": false, "closeness": 0.0670457550912457, "betweenness": 0.0, "shared_name": "187", "id": "187"}}, {"position": {"y": -321.70841354608535, "x": 250.89191676616667}, "selected": false, "data": {"name": "186", "degree": 1, "SUID": 74306, "selected": false, "closeness": 0.049311071486464575, "betweenness": 0.0, "shared_name": "186", "id": "186"}}, {"position": {"y": 39.03410964727402, "x": 219.73539210796355}, "selected": false, "data": {"name": "185", "degree": 1, "SUID": 74305, "selected": false, "closeness": 0.05538562377102905, "betweenness": 0.0, "shared_name": "185", "id": "185"}}, {"position": {"y": 324.3429170203209, "x": -75.03464268207551}, "selected": false, "data": {"name": "184", "degree": 1, "SUID": 74304, "selected": false, "closeness": 0.056200118238250066, "betweenness": 0.0, "shared_name": "184", "id": "184"}}, {"position": {"y": 100.43857436895371, "x": 199.405283465 ...

# %%
cy.render(network_views[2], styles["default"])
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cyba779cb9-43d5-45be-882e-5972686575a6 {
#         height: 700px;
#         width: 1160px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background-color: #fafafa;
#       }
#     </style>
#
#     <script>
#     (function() {
#       function render() {
#         $('#cyba779cb9-43d5-45be-882e-5972686575a6').cytoscape({
#             elements: {
#                 nodes: [{"position": {"y": -348.1010442972183, "x": -111.17915645718574}, "selected": false, "data": {"name": "199", "degree": 1, "SUID": 67733, "selected": false, "closeness": 0.05585620409741013, "betweenness": 0.0, "shared_name": "199", "id": "199"}}, {"position": {"y": 320.1694940328598, "x": 334.0504883182049}, "selected": false, "data": {"name": "198", "degree": 1, "SUID": 67732, "selected": false, "closeness": 0.03783624002364765, "betweenness": 0.0, "shared_name": "198", "id": "198"}}, {"position": {"y": -334.8380438089371, "x": 134.90732272982598}, "selected": false, "data": {"name": "197", "degree": 1, "SUID": 67731, "selected": false, "closeness": 0.055276381909547735, "betweenness": 0.0, "shared_name": "197", "id": "197"}}, {"position": {"y": -79.17866957187653, "x": 106.1733673465252}, "selected": false, "data": {"name": "196", "degree": 1, "SUID": 67730, "selected": false, "closeness": 0.05487665600730928, "betweenness": 0.0, "shared_name": "196", "id": "196"}}, {"position": {"y": -356.3130804300308, "x": -