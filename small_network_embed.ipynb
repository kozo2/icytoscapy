# %%
import cytoscape.viewer as cy, json

# %%
cy.embedShare('http://goo.gl/gXPRuq', 00)
# Out:
#         <iframe
#             width="800"
#             height=700"
#             src="http://goo.gl/gXPRuq"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Load network file generated in Cytoscape 3.1.x
yeast_network_file = open('yeast2.cyjs')
yeast_network = json.load(yeast_network_file)

# %%
visual_style_file = open('style.json')
vs_collection = json.load(visual_style_file)
styles = {}
for style in vs_collection:
    style_settings = style['style']
    title = style['title']
    styles[title] = style_settings

# %%
cy.render(yeast_network, styles['default'], 'preset', 500)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cy91ef196a-b3e2-48f2-b7ae-3ec2a8d15276 {
#         height: 500px;
#         width: 1160px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background-color: #fafafa;
#       }
#     </style>
#
#     <script>
#     (function() {
#
#         function render() {
#             $('#cy91ef196a-b3e2-48f2-b7ae-3ec2a8d15276').cytoscape({
#                 elements: {
# ...

# %%
cy.render(yeast_network, styles['Directed'])
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cy84abc46a-6e6d-463b-a145-40db8a1bc352 {
#         height: 700px;
#         width: 1160px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background-color: #fafafa;
#       }
#     </style>
#
#     <script>
#     (function() {
#
#         function render() {
#             $('#cy84abc46a-6e6d-463b-a145-40db8a1bc352').cytoscape({
#                 elements: {
# ...
