# %% [markdown]
# # Sample Workflow with Cytoscape and Cytoscape.js

# %%
# Load libraries
from IPython.html.widgets import interact
from IPython.html.widgets import *
from IPython.html import widgets
import cytoscape.viewer as cy
import json
import networkx as nx
from igraph import *

# %matplotlib inline
import matplotlib.pyplot as plt

import requests

import pandas as pd

# %%
# Make sure Cytoscape  RESTful API is running!
cytoscape_version = requests.get('http://localhost:8080/v1/version')
print("Cytoscape version is " +  json.loads(cytoscape_version.text)["cytoscapeVersion"])

res = requests.get('http://localhost:8080/v1/networks/count')
print(res.text)
# Out:
# Cytoscape version is 3.1.0
# {"networkCount":0}

# %% [markdown]
# ## Import & Generate Data in Python
#
# ### Generate scale-free graphs with NetworkX

# %%
graphs = []

for i in range(5):
    # Generate scale-free graph
    g = nx.scale_free_graph(100);
    
    # Perform simple graph analysis
    
    # Node statistics
    bc = nx.betweenness_centrality(g)
    degree = nx.degree(g)
    cc = nx.closeness_centrality(g)
    nx.set_node_attributes(g, 'betweenness', bc)
    nx.set_node_attributes(g, 'closeness', cc)
    nx.set_node_attributes(g, 'degree', degree)
    
    # Network statistics
    g.graph["avg_shortest_path_len"] = nx.average_shortest_path_length(g)
    g.graph["density"] = nx.density(g)
    graphs.append(g)


# Calculate statistics on the network

# Visualize with matplotlib
# nx.draw(graphs[0])
# plt.show()

# %% [markdown]
# ### Send all network models to Cytoscape

# %%
# Remove all networks
requests.delete('http://localhost:8080/v1/networks')

headers = {'Content-Type': 'application/json'}

for graph in graphs:
    cyjs_network = cy.from_networkx(graph)
    res1 = requests.post("http://localhost:8080/v1/networks?collection=Networks1", data=json.dumps(cyjs_network), headers=headers)
    result = json.loads(res1.content)
    network_suid = result["networkSUID"]
    res2 = requests.get("http://localhost:8080/v1/apply/layouts/force-directed/" + str(network_suid))

# %% [markdown]
# ## (Now graphs are in Cytoscape.  Do analysis, visualization, etc...)

# %% [markdown]
# ## Get the visualization back to this notebook.

# %%
response = requests.get("http://localhost:8080/v1/networks?format=SUID")
network_list = json.loads(response.content)
print(network_list)

network_views = []
for suid in network_list:
    response2 = requests.get("http://localhost:8080/v1/networks/" + str(suid) + "/views/first")
    network_views.append(json.loads(response2.content))
# Out:
# [410, 1427, 1096, 768, 52]

# %%
# Visual Style can be a simple Python object!

my_style = {
  "title" : "My Style 1",
  "defaults" : [ {
    "visualProperty" : "EDGE_WIDTH",
    "value" : 1.0
  }, {
    "visualProperty" : "EDGE_STROKE_UNSELECTED_PAINT",
    "value" : "#00ddff"
  }],
  "mappings" : [ {
    "mappingType" : "discrete",
    "mappingColumn" : "degree",
    "mappingColumnType" : "Integer",
    "visualProperty" : "NODE_FILL_COLOR",
    "map" : [ {
      "key" : "1",
      "value" : "#440055"
    }, {
      "key" : "4",
      "value" : "#00FF11"
    } ]
  }, {
    "mappingType" : "passthrough",
    "mappingColumn" : "name",
    "mappingColumnType" : "String",
    "visualProperty" : "NODE_LABEL"
  } ]
}

requests.post("http://localhost:8080/v1/styles", data=json.dumps(my_style), headers=headers)
# Out:
# <Response [204]>

# %% [markdown]
# ## Generate Visual Style Programatically

# %%
style_res = requests.get("http://localhost:8080/v1/styles/My%20Style%201")
style_array = json.loads(style_res.content)
style2 = style_array[0]['style']

cy.render(network_views[1], style2)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cy17471a27-11e8-4e31-94b9-295d24717a32 {
#         height: 700px;
#         width: 1160px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background-color: #fafafa;
#       }
#     </style>
#
#     <script>
#     (function() {
#       function render() {
#         $('#cy17471a27-11e8-4e31-94b9-295d24717a32').cytoscape({
#             elements: {
#                 nodes: [{"position": {"y": 566.0, "x": 495.0}, "selected": false, "data": {"name": "0", "degree": 58, "SUID": 1536, "selected": false, "closeness": 0.05454545454545454, "betweenness": 0.03365285508142651, "shared_name": "0", "id": "0"}}, {"position": {"y": 221.0, "x": 525.0}, "selected": false, "data": {"name": "1", "degree": 24, "SUID": 1535, "selected": false, "closeness": 0.05454545454545454, "betweenness": 0.021026592455163882, "shared_name": "1", "id": "1"}}, {"position": {"y": 391.0, "x": 801.0}, "selected": false, "data": {"name": "2", "degree": 89, "SUID": 1534, "selected": false, "closeness": 0.05844155844155845, "betweenness": 0.045351473922902494, "shared_name": "2", "id": "2"}}, {"position": {"y": 401.0, "x": 619.0}, "selected": false, "data": {"name": "3", "degree": 3, "SUID": 1533, "selected": false, "closeness": 0.05611672278338945, "betweenness": 0.0, "shared_name": "3", "id": "3"}}, {"position": {"y": 437.0, "x": 1174.0}, "selected": false, "data": {"name": "4", "degree": 5, "SUID": 1532, "selected": false, "closeness": 0.0, "betweenness": 0.0, "shared_name": "4", "id": "4"}}, {"position": {"y": 745.0, "x": 342.0}, "selected": false, "data": {"name": "5", "degree": 1, "SUID": 1531, "selected": false, "closeness": 0.04040404040404041, "betweenness": 0.0, "shared_name": "5", "id": "5"}}, {"position": {"y": 396.0, "x": 357.5}, "selected": false, "data": {"name": "6", "degree": 8, "SUID": 1530, "selected": false, "closeness": 0.060966810966810975, "betweenness": 0.0006184291898577612, "shared_name": "6", "id": "6"}}, {"position": {"y": 506.0, "x": 392.0}, "selected": false, "data": {"name": "7", "degree": 3, "SUID": 1529, "selected": false, "closeness": 0.04700854700854701, "betweenness": 0.0, "shared_name": "7", "id": "7"}}, {"position": {"y": 389.0, "x": 543.0}, "selected": false, "data": {"name": "8", "degree": 7, "SUID": 1528, "selected": false, "closeness": 0.08249158249158249, "betweenness": 0.0, "shared_name": "8", "id": "8"}}, {"position": {"y": 409.0, "x": 414.0}, "selected": false, "data": {"name": "9", "degree": 4, "SUID": 1527, "selected": false, "closeness": 0.0, "betweenness": 0.0, "shared_name": "9", "id": "9"}}, {"position": {"y": 507.0, "x": 720.0}, "selected": false, "data": {"name": "10", "degree": 2, "SUID": 1526, "selected": false, "closeness": 0.048100048100048094, "betweenness": 0.0, "shared_name": "10", "id": "10"}}, {"position": {"y": 429.0, "x": 554.0}, "selected": false, "data": {"name": "11", "degree": 8, "SUID": 1525, "selected": false, "closeness": 0.059417706476530004, "betweenness": 0.00041228612657184083, "shared_name": "11", "id": "11"}}, {"position": {"y": 690.0, "x": 752.0}, "selected": false, "data": {"name": "12", "degree": 5, "SUID": 1524, "selected": false, "closeness": 0.043062200956937795, "betweenness": 0.0018552875695732837, "shared_name": "12", "id": "12"}}, {"position": {"y": 547.0, "x": 629.0}, "selected": false, "data": {"name": "13", "degree": 6, "SUID": 1523, "selected": false, "closeness": 0.050505050505050504, "betweenness": 0.0, "shared_name": "13", "id": "13"}}, {"position": {"y": 716.0, "x": 574.0}, "selected": false, "data": {"name": "14", "degree": 2, "SUID": 1522, "selected": false, "closeness": 0.04040404040404041, "betweenness": 0.0, "shared_name": "14", "id": "14"}}, {"position": {"y": 363.0, "x": 604.0}, "selected": false, "data": {"name": "15", "degree": 2, "SUID": 1521, "selected": false, "closeness": 0.04591368227731864, "betweenness": 0.0, "shared_name": "15", "id": "15"}}, {"position": {"y": 478.2910897648519, "x": 356.28898996160945}, "selected": false, "data": {"name": "16", "degree": 1, "SUID": 1520, "selected": false, "closeness": 0.0, "betweenness": 0.0, "shared_name": "16", "id": "16"}}, {"position": {"y": 224.0, "x": 606.0}, "selected": false, "data": {"name": "17", "degree": 2, "SUID": 1519, "selected": false, "closeness": 0.048888888888888885, "betweenness": 0.0, "shared_name": "17", "id": "17"}}, {"position": {"y": 480.0,  ...
